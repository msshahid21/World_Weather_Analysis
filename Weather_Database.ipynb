# %% [markdown]
# # Import Dependencies

# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library
import requests

# Import the API keys
from config import weather_api_key

# Import the time library
import time

# %% [markdown]
# # Retrieve Weather Data

# %% [markdown]
# ## Generate Random Lats and Lngs

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90, high = 90, size = 2000)
lngs = np.random.uniform(low = -180, high = 180, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list for holding the cities
cities = []
coordinates = list(lat_lngs)

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)

# %% [markdown]
# ## Get Latitude, Longitude, Max Temp, Humidity, Cloudiness, and Wind Speed for Each City

# %%
# Starting URL for Weather Map API Call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning of Data Retrieval")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count += 1
        time.sleep(5)
        
    # Create endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data_list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,                          
                          "Current Description": city_weather_description})
    
    #If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
        
# Indicate that Data loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning of Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | qaanaaq
# Processing Record 2 of Set 1 | aqtobe
# Processing Record 3 of Set 1 | presidente epitacio
# Processing Record 4 of Set 1 | san carlos de bariloche
# Processing Record 5 of Set 1 | saint-philippe
# Processing Record 6 of Set 1 | igarka
# Processing Record 7 of Set 1 | aksarka
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | chokurdakh
# Processing Record 10 of Set 1 | baykit
# Processing Record 11 of Set 1 | butaritari
# Processing Record 12 of Set 1 | thompson
# Processing Record 13 of Set 1 | nacunday
# City not found. Skipping...
# Processing Record 14 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | upata
# Processing Record 19 of Set 1 | cidreira
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | ponta do sol
# Processing Record 22 of Set 1 | castro
# Processing Record 23 of Set 1 | ahipara
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | montgomery
# Processing Record 26 of Set 1 | tasiilaq
# Processing Record 27 of Set 1 | chipurupalle
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | longonjo
# Processing Record 30 of Set 1 | norman wells
# Processing Record 31 of Set 1 | babushkin
# Processing Record 32 of Set 1 | saskylakh
# Processing Record 33 of Set 1 | bay roberts
# Processing Record 34 of Set 1 | bonthe
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | lebu
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | oksfjord
# Processing Record 39 of Set 1 | frontera
# Processing Record 40 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | bara
# Processing Record 43 of Set 1 | chuy
# Processing Record 44 of Set 1 | izhma
# Processing Record 45 of Set 1 | borogontsy
# Processing Record 46 of Set 1 | clyde river
# Processing Record 47 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 1 | develi
# Processing Record 49 of Set 1 | benghazi
# Processing Record 50 of Set 1 | tiksi
# Processing Record 52 of Set 2 | punta arenas
# Processing Record 53 of Set 2 | airai
# Processing Record 54 of Set 2 | arraial do cabo
# Processing Record 55 of Set 2 | upernavik
# Processing Record 56 of Set 2 | hofn
# Processing Record 57 of Set 2 | east london
# Processing Record 58 of Set 2 | stornoway
# Processing Record 59 of Set 2 | hermanus
# Processing Record 60 of Set 2 | sawtell
# Processing Record 61 of Set 2 | geraldton
# Processing Record 62 of Set 2 | mar del plata
# Processing Record 63 of Set 2 | vila
# Processing Record 64 of Set 2 | matara
# Processing Record 65 of Set 2 | preobrazheniye
# Processing Record 66 of Set 2 | port alfred
# Processing Record 67 of Set 2 | puerto ayora
# Processing Record 68 of Set 2 | burica
# City not found. Skipping...
# Processing Record 69 of Set 2 | taltal
# Processing Record 70 of Set 2 | bredasdorp
# Processing Record 71 of Set 2 | barrow
# Processing Record 72 of Set 2 | ajdabiya
# Processing Record 73 of Set 2 | kuryk
# Processing Record 74 of Set 2 | oranjemund
# Processing Record 75 of Set 2 | san clemente
# Processing Record 76 of Set 2 | kimbe
# Processing Record 77 of Set 2 | omboue
# Processing Record 78 of Set 2 | alexandria
# Processing Record 79 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 80 of Set 2 | nelson bay
# Processing Record 81 of Set 2 | rio grande
# Processing Record 82 of Set 2 | carnarvon
# Processing Record 83 of Set 2 | kapaa
# Processing Record 84 of Set 2 | caranavi
# Processing Record 85 of Set 2 | longyearbyen
# Processing Record 86 of Set 2 | hede
# Processing Record 87 of Set 2 | huarmey
# Processing Record 88 of Set 2 | comarapa
# Processing Record 89 of Set 2 | kibre mengist
# Processing Record 90 of Set 2 | leningradskiy
# Processing Record 91 of Set 2 | rikitea
# Processing Record 92 of Set 2 | bethel
# Processing Record 93 of Set 2 | batemans bay
# Processing Record 94 of Set 2 | nikolskoye
# Processing Record 95 of Set 2 | caravelas
# Processing Record 96 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 97 of Set 2 | pudozh
# Processing Record 98 of Set 2 | georgetown
# Processing Record 99 of Set 2 | torres
# Processing Record 100 of Set 2 | cherskiy
# Processing Record 101 of Set 2 | narsaq
# Processing Record 103 of Set 3 | khandyga
# Processing Record 104 of Set 3 | renqiu
# Processing Record 105 of Set 3 | lavrentiya
# Processing Record 106 of Set 3 | grants pass
# Processing Record 107 of Set 3 | cayenne
# Processing Record 108 of Set 3 | ulaangom
# Processing Record 109 of Set 3 | cape town
# Processing Record 110 of Set 3 | asyut
# Processing Record 111 of Set 3 | tautira
# Processing Record 112 of Set 3 | ak-dovurak
# Processing Record 113 of Set 3 | fukue
# Processing Record 114 of Set 3 | tateyama
# Processing Record 115 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 116 of Set 3 | bambanglipuro
# Processing Record 117 of Set 3 | shingu
# Processing Record 118 of Set 3 | jacareacanga
# Processing Record 119 of Set 3 | grindavik
# Processing Record 120 of Set 3 | bilma
# Processing Record 121 of Set 3 | torbay
# Processing Record 122 of Set 3 | conde
# Processing Record 123 of Set 3 | victoria
# Processing Record 124 of Set 3 | san patricio
# Processing Record 125 of Set 3 | roberto payan
# City not found. Skipping...
# Processing Record 126 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 127 of Set 3 | vaini
# Processing Record 128 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 129 of Set 3 | naze
# Processing Record 130 of Set 3 | masterton
# Processing Record 131 of Set 3 | vao
# Processing Record 132 of Set 3 | annau
# Processing Record 133 of Set 3 | lagoa
# Processing Record 134 of Set 3 | samarai
# Processing Record 135 of Set 3 | ranong
# Processing Record 136 of Set 3 | magadan
# Processing Record 137 of Set 3 | paita
# Processing Record 138 of Set 3 | pangody
# Processing Record 139 of Set 3 | ekhabi
# Processing Record 140 of Set 3 | tuktoyaktuk
# Processing Record 141 of Set 3 | kaitong
# Processing Record 142 of Set 3 | praia
# Processing Record 143 of Set 3 | oktyabrskoye
# Processing Record 144 of Set 3 | souillac
# Processing Record 145 of Set 3 | salalah
# Processing Record 146 of Set 3 | micheweni
# Processing Record 147 of Set 3 | nongan
# Processing Record 148 of Set 3 | kikwit
# Processing Record 149 of Set 3 | buraydah
# Processing Record 150 of Set 3 | ramsar
# Processing Record 151 of Set 3 | aklavik
# Processing Record 152 of Set 3 | nanortalik
# Processing Record 154 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 155 of Set 4 | faanui
# Processing Record 156 of Set 4 | jamestown
# Processing Record 157 of Set 4 | sisimiut
# Processing Record 158 of Set 4 | korla
# Processing Record 159 of Set 4 | namtsy
# Processing Record 160 of Set 4 | yanam
# Processing Record 161 of Set 4 | guerrero negro
# Processing Record 162 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 163 of Set 4 | hithadhoo
# Processing Record 164 of Set 4 | sao filipe
# Processing Record 165 of Set 4 | pisco
# Processing Record 166 of Set 4 | esperance
# Processing Record 167 of Set 4 | andros town
# Processing Record 168 of Set 4 | zhigansk
# Processing Record 169 of Set 4 | homer
# Processing Record 170 of Set 4 | tudora
# Processing Record 171 of Set 4 | tilichiki
# Processing Record 172 of Set 4 | baglan
# Processing Record 173 of Set 4 | poso
# Processing Record 174 of Set 4 | zhezkazgan
# Processing Record 175 of Set 4 | plettenberg bay
# Processing Record 176 of Set 4 | santa maria
# Processing Record 177 of Set 4 | villa del rosario
# Processing Record 178 of Set 4 | galesong
# Processing Record 179 of Set 4 | coquimbo
# Processing Record 180 of Set 4 | hoganas
# Processing Record 181 of Set 4 | changtu
# Processing Record 182 of Set 4 | abu dhabi
# Processing Record 183 of Set 4 | punta alta
# Processing Record 184 of Set 4 | kodiak
# Processing Record 185 of Set 4 | mount gambier
# Processing Record 186 of Set 4 | santa rosa
# Processing Record 187 of Set 4 | shobara
# Processing Record 188 of Set 4 | krasnaya polyana
# Processing Record 189 of Set 4 | okhotsk
# Processing Record 190 of Set 4 | gizo
# Processing Record 191 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 192 of Set 4 | nemuro
# Processing Record 193 of Set 4 | cosala
# Processing Record 194 of Set 4 | derzhavinsk
# Processing Record 195 of Set 4 | yellowknife
# Processing Record 196 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 197 of Set 4 | pueblo nuevo
# Processing Record 198 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 199 of Set 4 | iquique
# Processing Record 200 of Set 4 | bogande
# Processing Record 201 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 202 of Set 4 | vallenar
# Processing Record 203 of Set 4 | karoi
# Processing Record 205 of Set 5 | nouadhibou
# Processing Record 206 of Set 5 | cermik
# Processing Record 207 of Set 5 | mahebourg
# Processing Record 208 of Set 5 | awbari
# Processing Record 209 of Set 5 | iqaluit
# Processing Record 210 of Set 5 | ilulissat
# Processing Record 211 of Set 5 | buala
# Processing Record 212 of Set 5 | feni
# Processing Record 213 of Set 5 | gunjur
# Processing Record 214 of Set 5 | dikson
# Processing Record 215 of Set 5 | lompoc
# Processing Record 216 of Set 5 | lerwick
# Processing Record 217 of Set 5 | vakhrushev
# Processing Record 218 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 219 of Set 5 | san quintin
# Processing Record 220 of Set 5 | provideniya
# Processing Record 221 of Set 5 | kalaleh
# Processing Record 222 of Set 5 | hami
# Processing Record 223 of Set 5 | kruisfontein
# Processing Record 224 of Set 5 | kaitangata
# Processing Record 225 of Set 5 | alofi
# Processing Record 226 of Set 5 | kavaratti
# Processing Record 227 of Set 5 | mitsamiouli
# Processing Record 228 of Set 5 | ayan
# Processing Record 229 of Set 5 | yayva
# Processing Record 230 of Set 5 | kloulklubed
# Processing Record 231 of Set 5 | ribeira grande
# Processing Record 232 of Set 5 | chernyshevskiy
# Processing Record 233 of Set 5 | coahuayana
# Processing Record 234 of Set 5 | tura
# Processing Record 235 of Set 5 | lorengau
# Processing Record 236 of Set 5 | sambava
# Processing Record 237 of Set 5 | vrangel
# Processing Record 238 of Set 5 | naryan-mar
# Processing Record 239 of Set 5 | goderich
# Processing Record 240 of Set 5 | vardo
# Processing Record 241 of Set 5 | alice springs
# Processing Record 242 of Set 5 | krasnyy chikoy
# Processing Record 243 of Set 5 | karratha
# Processing Record 244 of Set 5 | tashtyp
# Processing Record 245 of Set 5 | kumbo
# Processing Record 246 of Set 5 | ngunguru
# Processing Record 247 of Set 5 | codrington
# Processing Record 248 of Set 5 | san francisco
# Processing Record 249 of Set 5 | dasoguz
# Processing Record 250 of Set 5 | tyrma
# Processing Record 251 of Set 5 | acajutla
# Processing Record 252 of Set 5 | high level
# Processing Record 253 of Set 5 | sawakin
# Processing Record 254 of Set 5 | burkhala
# City not found. Skipping...
# Processing Record 256 of Set 6 | turukhansk
# Processing Record 257 of Set 6 | sestri levante
# Processing Record 258 of Set 6 | huambo
# Processing Record 259 of Set 6 | bagotville
# Processing Record 260 of Set 6 | saldanha
# Processing Record 261 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 262 of Set 6 | karistos
# City not found. Skipping...
# Processing Record 263 of Set 6 | alta floresta
# Processing Record 264 of Set 6 | katsuura
# Processing Record 265 of Set 6 | yangambi
# Processing Record 266 of Set 6 | san andres
# Processing Record 267 of Set 6 | jacobina
# Processing Record 268 of Set 6 | chapais
# Processing Record 269 of Set 6 | la mana
# Processing Record 270 of Set 6 | mokhsogollokh
# Processing Record 271 of Set 6 | maldonado
# Processing Record 272 of Set 6 | charters towers
# Processing Record 273 of Set 6 | camacha
# Processing Record 274 of Set 6 | udala
# Processing Record 275 of Set 6 | ancud
# Processing Record 276 of Set 6 | brae
# Processing Record 277 of Set 6 | qingdao
# Processing Record 278 of Set 6 | luqiao
# Processing Record 279 of Set 6 | cabedelo
# Processing Record 280 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 281 of Set 6 | warri
# Processing Record 282 of Set 6 | sao gabriel da cachoeira
# Processing Record 283 of Set 6 | burnie
# Processing Record 284 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 285 of Set 6 | tabulbah
# City not found. Skipping...
# Processing Record 286 of Set 6 | tuatapere
# Processing Record 287 of Set 6 | cabo san lucas
# Processing Record 288 of Set 6 | raton
# Processing Record 289 of Set 6 | wawa
# Processing Record 290 of Set 6 | rawson
# Processing Record 291 of Set 6 | ixtapa
# Processing Record 292 of Set 6 | searcy
# Processing Record 293 of Set 6 | sakaraha
# Processing Record 294 of Set 6 | pevek
# Processing Record 295 of Set 6 | kasongo
# Processing Record 296 of Set 6 | henties bay
# Processing Record 297 of Set 6 | anlu
# Processing Record 298 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 299 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 300 of Set 6 | fonte boa
# Processing Record 301 of Set 6 | saint-pierre
# Processing Record 302 of Set 6 | muroto
# Processing Record 303 of Set 6 | talnakh
# Processing Record 304 of Set 6 | faya
# Processing Record 305 of Set 6 | presidencia roque saenz pena
# Processing Record 307 of Set 7 | concepcion del oro
# Processing Record 308 of Set 7 | kahta
# Processing Record 309 of Set 7 | solnechnyy
# Processing Record 310 of Set 7 | ballina
# Processing Record 311 of Set 7 | kavieng
# Processing Record 312 of Set 7 | bengkulu
# Processing Record 313 of Set 7 | gat
# Processing Record 314 of Set 7 | praia da vitoria
# Processing Record 315 of Set 7 | andenes
# Processing Record 316 of Set 7 | wahpeton
# Processing Record 317 of Set 7 | parana
# Processing Record 318 of Set 7 | byron bay
# Processing Record 319 of Set 7 | noumea
# Processing Record 320 of Set 7 | west point
# Processing Record 321 of Set 7 | puerto del rosario
# Processing Record 322 of Set 7 | isla vista
# Processing Record 323 of Set 7 | pangnirtung
# Processing Record 324 of Set 7 | skjervoy
# Processing Record 325 of Set 7 | trincomalee
# Processing Record 326 of Set 7 | tiznit
# Processing Record 327 of Set 7 | fortuna
# Processing Record 328 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 329 of Set 7 | nara
# Processing Record 330 of Set 7 | florida
# Processing Record 331 of Set 7 | duki
# Processing Record 332 of Set 7 | fairbanks
# Processing Record 333 of Set 7 | mocuba
# Processing Record 334 of Set 7 | cockburn town
# Processing Record 335 of Set 7 | taoudenni
# Processing Record 336 of Set 7 | jardim
# Processing Record 337 of Set 7 | eureka
# Processing Record 338 of Set 7 | maizuru
# Processing Record 339 of Set 7 | ijui
# Processing Record 340 of Set 7 | maumere
# Processing Record 341 of Set 7 | jibuti
# Processing Record 342 of Set 7 | key largo
# Processing Record 343 of Set 7 | hasaki
# Processing Record 344 of Set 7 | laguna
# Processing Record 345 of Set 7 | la vega
# Processing Record 346 of Set 7 | mackenzie
# Processing Record 347 of Set 7 | sidi qasim
# City not found. Skipping...
# Processing Record 348 of Set 7 | khani
# Processing Record 349 of Set 7 | bardiyah
# Processing Record 350 of Set 7 | chabahar
# Processing Record 351 of Set 7 | broome
# Processing Record 352 of Set 7 | shakawe
# Processing Record 353 of Set 7 | bacolod
# Processing Record 354 of Set 7 | kenora
# Processing Record 355 of Set 7 | calvinia
# Processing Record 356 of Set 7 | moranbah
# Processing Record 358 of Set 8 | te anau
# Processing Record 359 of Set 8 | bourail
# Processing Record 360 of Set 8 | formosa
# Processing Record 361 of Set 8 | coaraci
# Processing Record 362 of Set 8 | nanpara
# Processing Record 363 of Set 8 | wangqing
# Processing Record 364 of Set 8 | kathu
# Processing Record 365 of Set 8 | paramonga
# Processing Record 366 of Set 8 | yablonovo
# Processing Record 367 of Set 8 | sivas
# Processing Record 368 of Set 8 | sioux lookout
# Processing Record 369 of Set 8 | staritsa
# Processing Record 370 of Set 8 | coari
# Processing Record 371 of Set 8 | kaeo
# Processing Record 372 of Set 8 | skeldon
# Processing Record 373 of Set 8 | ponta delgada
# Processing Record 374 of Set 8 | shasta lake
# Processing Record 375 of Set 8 | hovd
# Processing Record 376 of Set 8 | creston
# Processing Record 377 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 378 of Set 8 | sakakah
# Processing Record 379 of Set 8 | raudeberg
# Processing Record 380 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 381 of Set 8 | vero beach
# Processing Record 382 of Set 8 | nizhniy kuranakh
# Processing Record 383 of Set 8 | blenheim
# Processing Record 384 of Set 8 | touros
# Processing Record 385 of Set 8 | soria
# Processing Record 386 of Set 8 | buluang
# Processing Record 387 of Set 8 | dargaville
# Processing Record 388 of Set 8 | klaksvik
# Processing Record 389 of Set 8 | point fortin
# Processing Record 390 of Set 8 | qabis
# City not found. Skipping...
# Processing Record 391 of Set 8 | biak
# Processing Record 392 of Set 8 | senanga
# Processing Record 393 of Set 8 | gardenstown
# Processing Record 394 of Set 8 | livadia
# Processing Record 395 of Set 8 | kapit
# Processing Record 396 of Set 8 | adra
# Processing Record 397 of Set 8 | quatre cocos
# Processing Record 398 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 399 of Set 8 | qasigiannguit
# Processing Record 400 of Set 8 | aripuana
# Processing Record 401 of Set 8 | dunbar
# Processing Record 402 of Set 8 | banda aceh
# Processing Record 403 of Set 8 | ada
# Processing Record 404 of Set 8 | namatanai
# Processing Record 405 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 406 of Set 8 | sur
# Processing Record 407 of Set 8 | pendleton
# Processing Record 409 of Set 9 | owase
# Processing Record 410 of Set 9 | dunedin
# Processing Record 411 of Set 9 | casma
# Processing Record 412 of Set 9 | bartica
# Processing Record 413 of Set 9 | morehead
# Processing Record 414 of Set 9 | khatanga
# Processing Record 415 of Set 9 | mahajanga
# Processing Record 416 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 417 of Set 9 | ler
# Processing Record 418 of Set 9 | eyl
# Processing Record 419 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 420 of Set 9 | yumen
# Processing Record 421 of Set 9 | rodrigues alves
# Processing Record 422 of Set 9 | lipin bor
# Processing Record 423 of Set 9 | sandy bay
# Processing Record 424 of Set 9 | waipawa
# Processing Record 425 of Set 9 | verkhoyansk
# Processing Record 426 of Set 9 | avera
# Processing Record 427 of Set 9 | champerico
# Processing Record 428 of Set 9 | koumac
# Processing Record 429 of Set 9 | richards bay
# Processing Record 430 of Set 9 | luwuk
# Processing Record 431 of Set 9 | najran
# Processing Record 432 of Set 9 | camana
# Processing Record 433 of Set 9 | araouane
# Processing Record 434 of Set 9 | waingapu
# Processing Record 435 of Set 9 | hatsukaichi
# Processing Record 436 of Set 9 | merrill
# Processing Record 437 of Set 9 | nantucket
# Processing Record 438 of Set 9 | mayaky
# Processing Record 439 of Set 9 | saint andrews
# Processing Record 440 of Set 9 | liverpool
# Processing Record 441 of Set 9 | anadyr
# Processing Record 442 of Set 9 | ostroleka
# Processing Record 443 of Set 9 | dawson creek
# Processing Record 444 of Set 9 | warrnambool
# Processing Record 445 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 446 of Set 9 | rognan
# Processing Record 447 of Set 9 | pokhara
# Processing Record 448 of Set 9 | forestville
# Processing Record 449 of Set 9 | muskogee
# Processing Record 450 of Set 9 | odweyne
# Processing Record 451 of Set 9 | srednekolymsk
# Processing Record 452 of Set 9 | mitu
# Processing Record 453 of Set 9 | beatrice
# Processing Record 454 of Set 9 | iskateley
# Processing Record 455 of Set 9 | kalmunai
# Processing Record 456 of Set 9 | rocha
# Processing Record 457 of Set 9 | hernani
# Processing Record 458 of Set 9 | beohari
# Processing Record 460 of Set 10 | linxi
# Processing Record 461 of Set 10 | la sarre
# Processing Record 462 of Set 10 | nago
# Processing Record 463 of Set 10 | shirokiy
# Processing Record 464 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 465 of Set 10 | atar
# Processing Record 466 of Set 10 | golden
# Processing Record 467 of Set 10 | gazanjyk
# Processing Record 468 of Set 10 | severodvinsk
# Processing Record 469 of Set 10 | mujiayingzi
# Processing Record 470 of Set 10 | meulaboh
# Processing Record 471 of Set 10 | honiara
# Processing Record 472 of Set 10 | kirakira
# Processing Record 473 of Set 10 | uige
# Processing Record 474 of Set 10 | conceicao da barra
# Processing Record 475 of Set 10 | severo-kurilsk
# Processing Record 476 of Set 10 | bambous virieux
# Processing Record 477 of Set 10 | thai binh
# Processing Record 478 of Set 10 | mawlaik
# Processing Record 479 of Set 10 | elizabeth city
# Processing Record 480 of Set 10 | yasnogorsk
# Processing Record 481 of Set 10 | puerto escondido
# Processing Record 482 of Set 10 | amalapuram
# Processing Record 483 of Set 10 | storsteinnes
# Processing Record 484 of Set 10 | matay
# Processing Record 485 of Set 10 | neuquen
# Processing Record 486 of Set 10 | den helder
# Processing Record 487 of Set 10 | iracoubo
# Processing Record 488 of Set 10 | komsomolskiy
# Processing Record 489 of Set 10 | hambantota
# Processing Record 490 of Set 10 | ustrzyki dolne
# Processing Record 491 of Set 10 | margate
# Processing Record 492 of Set 10 | muros
# Processing Record 493 of Set 10 | paamiut
# Processing Record 494 of Set 10 | kysyl-syr
# Processing Record 495 of Set 10 | ocos
# Processing Record 496 of Set 10 | fairview
# Processing Record 497 of Set 10 | sistranda
# Processing Record 498 of Set 10 | dunmore town
# Processing Record 499 of Set 10 | nome
# Processing Record 500 of Set 10 | yining
# Processing Record 501 of Set 10 | luderitz
# Processing Record 502 of Set 10 | thurso
# Processing Record 503 of Set 10 | podgornoye
# Processing Record 504 of Set 10 | husavik
# Processing Record 505 of Set 10 | tarauaca
# Processing Record 506 of Set 10 | the valley
# Processing Record 507 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 508 of Set 10 | constitucion
# Processing Record 509 of Set 10 | ayr
# Processing Record 511 of Set 11 | orange cove
# Processing Record 512 of Set 11 | zhangjiakou
# Processing Record 513 of Set 11 | muyezerskiy
# Processing Record 514 of Set 11 | buin
# Processing Record 515 of Set 11 | marevo
# Processing Record 516 of Set 11 | maragogi
# Processing Record 517 of Set 11 | faridpur
# Processing Record 518 of Set 11 | haines junction
# Processing Record 519 of Set 11 | san isidro
# Processing Record 520 of Set 11 | port blair
# Processing Record 521 of Set 11 | evensk
# Processing Record 522 of Set 11 | kungurtug
# Processing Record 523 of Set 11 | adrar
# Processing Record 524 of Set 11 | cascais
# Processing Record 525 of Set 11 | ciudad ojeda
# Processing Record 526 of Set 11 | ipojuca
# Processing Record 527 of Set 11 | gawler
# Processing Record 528 of Set 11 | baherden
# Processing Record 529 of Set 11 | angoram
# Processing Record 530 of Set 11 | verkhnyaya inta
# Processing Record 531 of Set 11 | pombas
# Processing Record 532 of Set 11 | coihaique
# Processing Record 533 of Set 11 | clarence town
# Processing Record 534 of Set 11 | ferkessedougou
# Processing Record 535 of Set 11 | miandrivazo
# Processing Record 536 of Set 11 | axim
# Processing Record 537 of Set 11 | kuala terengganu
# Processing Record 538 of Set 11 | dalbandin
# Processing Record 539 of Set 11 | college
# Processing Record 540 of Set 11 | hamilton
# Processing Record 541 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 542 of Set 11 | zhuzhou
# Processing Record 543 of Set 11 | powell
# Processing Record 544 of Set 11 | lata
# Processing Record 545 of Set 11 | bowen
# Processing Record 546 of Set 11 | kodinsk
# Processing Record 547 of Set 11 | batu
# Processing Record 548 of Set 11 | egvekinot
# Processing Record 549 of Set 11 | harper
# Processing Record 550 of Set 11 | riyadh
# Processing Record 551 of Set 11 | pavlovsk
# Processing Record 552 of Set 11 | aykhal
# Processing Record 553 of Set 11 | pereslavl-zalesskiy
# Processing Record 554 of Set 11 | pozo colorado
# Processing Record 555 of Set 11 | manggar
# Processing Record 556 of Set 11 | lichinga
# Processing Record 557 of Set 11 | zemio
# Processing Record 558 of Set 11 | dutlwe
# Processing Record 559 of Set 11 | jiwani
# Processing Record 560 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 562 of Set 12 | kaili
# Processing Record 563 of Set 12 | oriximina
# Processing Record 564 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 565 of Set 12 | gornyak
# Processing Record 566 of Set 12 | bukama
# Processing Record 567 of Set 12 | bahia honda
# Processing Record 568 of Set 12 | chik
# Processing Record 569 of Set 12 | palmer
# Processing Record 570 of Set 12 | ashoknagar
# Processing Record 571 of Set 12 | yambio
# Processing Record 572 of Set 12 | ostrovnoy
# Processing Record 573 of Set 12 | lodja
# Processing Record 574 of Set 12 | watsa
# Processing Record 575 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 576 of Set 12 | dingle
# Processing Record 577 of Set 12 | union
# Processing Record 578 of Set 12 | garissa
# Processing Record 579 of Set 12 | sitka
# Processing Record 580 of Set 12 | riberalta
# Processing Record 581 of Set 12 | iralaya
# Processing Record 582 of Set 12 | mikhaylovka
# Processing Record 583 of Set 12 | villazon
# Processing Record 584 of Set 12 | basco
# Processing Record 585 of Set 12 | dakoro
# Processing Record 586 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 587 of Set 12 | boysun
# Processing Record 588 of Set 12 | mtwara
# Processing Record 589 of Set 12 | kamenka
# Processing Record 590 of Set 12 | porto-vecchio
# Processing Record 591 of Set 12 | padang
# Processing Record 592 of Set 12 | qax
# Processing Record 593 of Set 12 | antalaha
# Processing Record 594 of Set 12 | olafsvik
# Processing Record 595 of Set 12 | kirkwall
# Processing Record 596 of Set 12 | inirida
# Processing Record 597 of Set 12 | mabai
# Processing Record 598 of Set 12 | adzope
# Processing Record 599 of Set 12 | linhares
# Processing Record 600 of Set 12 | tefe
# Processing Record 601 of Set 12 | mareeba
# Processing Record 602 of Set 12 | owando
# Processing Record 603 of Set 12 | cumra
# Processing Record 604 of Set 12 | porto santo
# Processing Record 605 of Set 12 | mutoko
# Processing Record 606 of Set 12 | dorado
# Processing Record 607 of Set 12 | baruun-urt
# Processing Record 608 of Set 12 | george
# Processing Record 609 of Set 12 | suwalki
# Processing Record 610 of Set 12 | pak phanang
# Processing Record 611 of Set 12 | tonkino
# Processing Record 613 of Set 13 | khorixas
# Processing Record 614 of Set 13 | araripe
# Processing Record 615 of Set 13 | santiago de cuba
# Processing Record 616 of Set 13 | ishigaki
# Processing Record 617 of Set 13 | tual
# Processing Record 618 of Set 13 | yerbogachen
# Processing Record 619 of Set 13 | vostochnyy
# Processing Record 620 of Set 13 | zonguldak
# Processing Record 621 of Set 13 | port shepstone
# Processing Record 622 of Set 13 | zachagansk
# City not found. Skipping...
# Processing Record 623 of Set 13 | marawi
# Processing Record 624 of Set 13 | mao
# Processing Record 625 of Set 13 | wewak
# Processing Record 626 of Set 13 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 627 of Set 13 | beira
# Processing Record 628 of Set 13 | butembo
# Processing Record 629 of Set 13 | pacific grove
# Processing Record 630 of Set 13 | vaitape
# Processing Record 631 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 632 of Set 13 | morant bay
# Processing Record 633 of Set 13 | boyolangu
# Processing Record 634 of Set 13 | ossora
# Processing Record 635 of Set 13 | magdagachi
# Processing Record 636 of Set 13 | green river
# Processing Record 637 of Set 13 | olinda
# Processing Record 638 of Set 13 | ginda
# Processing Record 639 of Set 13 | mandalgovi
# Processing Record 640 of Set 13 | lasa
# Processing Record 641 of Set 13 | asau
# Processing Record 642 of Set 13 | parit buntar
# Processing Record 643 of Set 13 | sola
# Processing Record 644 of Set 13 | mazagao
# Processing Record 645 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 646 of Set 13 | diego de almagro
# Processing Record 647 of Set 13 | chakulia
# Processing Record 648 of Set 13 | bere
# Processing Record 649 of Set 13 | soligalich
# Processing Record 650 of Set 13 | malindi
# Processing Record 651 of Set 13 | marsh harbour
# Processing Record 652 of Set 13 | asekeyevo
# Processing Record 653 of Set 13 | soyo
# Processing Record 654 of Set 13 | hervey bay
# Processing Record 655 of Set 13 | cooma
# Processing Record 656 of Set 13 | erenhot
# Processing Record 657 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 658 of Set 13 | beringovskiy
# Processing Record 659 of Set 13 | funadhoo
# Processing Record 660 of Set 13 | havelock
# Processing Record 661 of Set 13 | dicabisagan
# Processing Record 662 of Set 13 | vila do maio
# Processing Record 664 of Set 14 | ilo
# Processing Record 665 of Set 14 | bafq
# Processing Record 666 of Set 14 | kuching
# Processing Record 667 of Set 14 | nha trang
# Processing Record 668 of Set 14 | san cristobal
# Processing Record 669 of Set 14 | acapulco
# Processing Record 670 of Set 14 | puerto leguizamo
# Processing Record 671 of Set 14 | haverfordwest
# Processing Record 672 of Set 14 | dauphin
# Processing Record 673 of Set 14 | wilmington
# Processing Record 674 of Set 14 | deputatskiy
# Processing Record 675 of Set 14 | saint anthony
# Processing Record 676 of Set 14 | naral
# City not found. Skipping...
# Processing Record 677 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 678 of Set 14 | tres arroyos
# Processing Record 679 of Set 14 | maniitsoq
# Processing Record 680 of Set 14 | chopovychi
# Processing Record 681 of Set 14 | malinovoye ozero
# Processing Record 682 of Set 14 | saquena
# Processing Record 683 of Set 14 | jawhar
# Processing Record 684 of Set 14 | auki
# Processing Record 685 of Set 14 | atikokan
# Processing Record 686 of Set 14 | totness
# Processing Record 687 of Set 14 | oskemen
# Processing Record 688 of Set 14 | boende
# Processing Record 689 of Set 14 | kyren
# Processing Record 690 of Set 14 | north bend
# Processing Record 691 of Set 14 | katangli
# Processing Record 692 of Set 14 | kaupanger
# Processing Record 693 of Set 14 | denpasar
# Processing Record 694 of Set 14 | ambilobe
# Processing Record 695 of Set 14 | kailua
# Processing Record 696 of Set 14 | bathsheba
# Processing Record 697 of Set 14 | yulara
# Processing Record 698 of Set 14 | qiqihar
# Processing Record 699 of Set 14 | ha tinh
# Processing Record 700 of Set 14 | jiayuguan
# Processing Record 701 of Set 14 | san jeronimo
# Processing Record 702 of Set 14 | bilibino
# Processing Record 703 of Set 14 | lincolnton
# Processing Record 704 of Set 14 | roald
# Processing Record 705 of Set 14 | niksar
# Processing Record 706 of Set 14 | bajil
# Processing Record 707 of Set 14 | barcelona
# Processing Record 708 of Set 14 | yar-sale
# Processing Record 709 of Set 14 | brigham city
# Processing Record 710 of Set 14 | north platte
# Processing Record 711 of Set 14 | sterling
# Processing Record 712 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 713 of Set 14 | ransang
# Processing Record 715 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 716 of Set 15 | tocopilla
# Processing Record 717 of Set 15 | edinburg
# Processing Record 718 of Set 15 | sao joao da barra
# Processing Record 719 of Set 15 | lengshuijiang
# Processing Record 720 of Set 15 | itarema
# Processing Record 721 of Set 15 | sembe
# Processing Record 722 of Set 15 | hirara
# Processing Record 723 of Set 15 | jizan
# Processing Record 724 of Set 15 | loiza
# Processing Record 725 of Set 15 | mehamn
# Processing Record 726 of Set 15 | pontalina
# Processing Record 727 of Set 15 | saint george
# Processing Record 728 of Set 15 | keti bandar
# Processing Record 729 of Set 15 | lucea
# Processing Record 730 of Set 15 | kalemie
# Processing Record 731 of Set 15 | ulladulla
# Processing Record 732 of Set 15 | trabzon
# Processing Record 733 of Set 15 | alamos
# Processing Record 734 of Set 15 | ola
# Processing Record 735 of Set 15 | ramotswa
# Processing Record 736 of Set 15 | bar harbor
# Processing Record 737 of Set 15 | challans
# Processing Record 738 of Set 15 | tongliao
# Processing Record 739 of Set 15 | salinopolis
# Processing Record 740 of Set 15 | rio viejo
# Processing Record 741 of Set 15 | campbell river
# Processing Record 742 of Set 15 | puerto madryn
# Processing Record 743 of Set 15 | maghama
# City not found. Skipping...
# Processing Record 744 of Set 15 | yuzawa
# Processing Record 745 of Set 15 | rio gallegos
# Processing Record 746 of Set 15 | taunton
# Processing Record 747 of Set 15 | taga
# Processing Record 748 of Set 15 | mutis
# Processing Record 749 of Set 15 | jackson
# Processing Record 750 of Set 15 | moose factory
# Processing Record 751 of Set 15 | broken hill
# Processing Record 752 of Set 15 | darab
# Processing Record 753 of Set 15 | le port
# Processing Record 754 of Set 15 | bousso
# Processing Record 755 of Set 15 | caleta de carquin
# Processing Record 756 of Set 15 | kolo
# Processing Record 757 of Set 15 | suntar
# Processing Record 758 of Set 15 | kununurra
# Processing Record 759 of Set 15 | ciudad bolivar
# Processing Record 760 of Set 15 | svetlyy
# Processing Record 761 of Set 15 | majene
# Processing Record 762 of Set 15 | sheregesh
# Processing Record 763 of Set 15 | balkhash
# Processing Record 764 of Set 15 | miramar
# Processing Record 766 of Set 16 | sorland
# Processing Record 767 of Set 16 | upington
# Processing Record 768 of Set 16 | oksbol
# Processing Record 769 of Set 16 | esmeraldas
# Processing Record 770 of Set 16 | novoagansk
# Processing Record 771 of Set 16 | linares
# Processing Record 772 of Set 16 | qitaihe
# Processing Record 773 of Set 16 | ilabaya
# Processing Record 774 of Set 16 | baoding
# Processing Record 775 of Set 16 | jieshi
# Processing Record 776 of Set 16 | matadi
# Processing Record 777 of Set 16 | salta
# Processing Record 778 of Set 16 | berlevag
# Processing Record 779 of Set 16 | billings
# Processing Record 780 of Set 16 | tres picos
# Processing Record 781 of Set 16 | teya
# Processing Record 782 of Set 16 | vereeniging
# Processing Record 783 of Set 16 | rehoboth
# Processing Record 784 of Set 16 | russell
# Processing Record 785 of Set 16 | chateau-thierry
# Processing Record 786 of Set 16 | zhigalovo
# Processing Record 787 of Set 16 | bonavista
# Processing Record 788 of Set 16 | maragheh
# Processing Record 789 of Set 16 | tambilil
# Processing Record 790 of Set 16 | kroya
# Processing Record 791 of Set 16 | belyy yar
# Processing Record 792 of Set 16 | kasempa
# Processing Record 793 of Set 16 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 794 of Set 16 | buritizeiro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ## Convert to Pandas DataFrame

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#                       City Country      Lat      Lng  Max Temp  Humidity  \
# 0                  Qaanaaq      GL  77.4840 -69.3632     33.12        80
# 1                   Aqtobe      KZ  50.2797  57.2072     60.89        67
# 2      Presidente Epitacio      BR -21.7633 -52.1156     70.97        53
# 3  San Carlos De Bariloche      AR -41.1456 -71.3082     40.75        81
# 4           Saint-Philippe      RE -21.3585  55.7679     69.39        76
#
#    Cloudiness  Wind Speed Current Description
# 0          15        2.73          few clouds
# 1           0        4.47           clear sky
# 2           0        6.55           clear sky
# 3          40       19.57    scattered clouds
# 4           8        8.39           clear sky

# %%
# Changing the column order
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]

# %%
# Create the output file (CSV)
output_data_file = 'Weather_Database/WeatherPy_Database.csv'

# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label = "City_ID")
